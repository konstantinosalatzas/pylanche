# %%
import sqlite3

# %%
# Connect to db.
con = sqlite3.connect("../pylanche/state.db")
cur = con.cursor()

# %%
def select_all_from_state():
    res = cur.execute("SELECT * FROM state")
    print(res.fetchall())

# %%
def insert_into_state(table: str):
    cur.execute("""INSERT INTO state VALUES ('2', '{"id": "2", "key": "value"}')""")
    con.commit()

# %%
select_all_from_state()

# %%
insert_into_state(table="state")
